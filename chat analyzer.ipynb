# %%
import numpy as np
import pandas as pd
import re

# %%
f = open('WhatsApp Chat with AOC BACKEND.txt',encoding='utf-8')
data = f.read()

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2},\s\d{1,2}:\d{2}\s'

messages = re.split(pattern, data)[1:]
dates = re.findall(pattern, data)

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})

# %%
df.head()
# Out:
#                                         user_message    message_date
# 0  PM - Messages and calls are end-to-end encrypt...  1/16/23, 8:45
# 1  AM - Sir Eut Online Meeting created group "AOC...  1/6/23, 12:14
# 2   PM - You joined using this group's invite link\n  1/16/23, 8:45
# 3  PM - Umar Aslam joined using this group's invi...  1/16/23, 8:49
# 4         PM - Sir Eut Online Meeting: wasif u thr\n  1/16/23, 9:00

# %%
df['user_message'][0:5]
# Out:
# 0    PM - Messages and calls are end-to-end encrypt...
# 1    AM - Sir Eut Online Meeting created group "AOC...
# 2     PM - You joined using this group's invite link\n
# 3    PM - Umar Aslam joined using this group's invi...
# 4           PM - Sir Eut Online Meeting: wasif u thr\n
# Name: user_message, dtype: object

# %%
df['user_message'] = df['user_message'].map(lambda x: x.lstrip('PM - '))
df['user_message'] = df['user_message'].map(lambda x: x.lstrip('AM - '))

# %%
df.head()
# Out:
#                                         user_message    message_date
# 0  essages and calls are end-to-end encrypted. No...  1/16/23, 8:45
# 1  Sir Eut Online Meeting created group "AOC BACK...  1/6/23, 12:14
# 2        You joined using this group's invite link\n  1/16/23, 8:45
# 3  Umar Aslam joined using this group's invite li...  1/16/23, 8:49
# 4              Sir Eut Online Meeting: wasif u thr\n  1/16/23, 9:00

# %%
# convert message_date type
df['message_date'] = pd.to_datetime(df['message_date'], infer_datetime_format=True)
df['message_date'] = pd.to_datetime(df['message_date'], format='%m/%d/%y, %H:%M')
df.rename(columns={'message_date': 'date'}, inplace=True)

# %%
df.head(2)
# Out:
#                                         user_message                date
# 0  essages and calls are end-to-end encrypted. No... 2023-01-16 08:45:00
# 1  Sir Eut Online Meeting created group "AOC BACK... 2023-01-06 12:14:00

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

df['only_date'] = df['date'].dt.date
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

period = []
for hour in df[['day_name', 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour + 1))
    else:
        period.append(str(hour) + "-" + str(hour + 1))

df['period'] = period

# %%
df.head()
# Out:
#                  date                    user  \
# 0 2023-01-16 08:45:00      group_notification
# 1 2023-01-06 12:14:00      group_notification
# 2 2023-01-16 08:45:00      group_notification
# 3 2023-01-16 08:49:00      group_notification
# 4 2023-01-16 09:00:00  Sir Eut Online Meeting
#
#                                              message   only_date  year  \
# 0  essages and calls are end-to-end encrypted. No...  2023-01-16  2023
# 1  Sir Eut Online Meeting created group "AOC BACK...  2023-01-06  2023
# 2        You joined using this group's invite link\n  2023-01-16  2023
# 3  Umar Aslam joined using this group's invite li...  2023-01-16  2023
# 4                                      wasif u thr\n  2023-01-16  2023
#
#    month_num    month  day day_name  hour  minute period
# 0          1  January   16   Monday     8      45    8-9
# 1          1  January    6   Friday    12      14  12-13
# 2          1  January   16   Monday     8      45    8-9
# 3          1  January   16   Monday     8      49    8-9
# 4          1  January   16   Monday     9       0   9-10

# %% [markdown]
# #
# # code analyzing

# %%
df['user'][30:100]
# Out:
# 30         Umar Aslam
# 31          Wasif Eut
# 32          Wasif Eut
# 33         Umar Aslam
# 34     Syed Afaq Shah
#            ...
# 95         Umar Aslam
# 96          Wasif Eut
# 97    +92 333 5010840
# 98          Wasif Eut
# 99     Syed Afaq Shah
# Name: user, Length: 70, dtype: object

# %%
# fetch the number of messages
num_messages = df.shape[0]
num_messages
# Out:
# 189

# %%
# fetch the total number of words
words = []
for message in df['message']:
    #print(message.split()) 
    words.extend(message.split())
words
# Out:
# ['essages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'No',
#  'one',
#  'outside',
#  'of',
#  'this',
#  'chat,',
#  'not',
#  'even',
#  'WhatsApp,',
#  'can',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'them.',
#  'Tap',
#  'to',
#  'learn',
#  'more.',
#  'Sir',
#  'Eut',
#  'Online',
#  'Meeting',
#  'created',
#  'group',
#  '"AOC',
#  'BACKEND"',
#  'You',
#  'joined',
#  'using',
#  'this',
#  "group's",
#  'invite',
#  'link',
#  'Umar',
#  'Aslam',
#  'joined',
#  'using',
#  'this',
#  "group's",
#  'invite',
#  'link',
#  'wasif',
#  'u',
#  'thr',
#  'Yes',
#  'sir',
#  'im',
#  'waiting',
#  'for',
#  '30',
#  'min,',
#  'sent',
#  'tried',
#  'many',
#  'times',
#  'with',
#  'google',
#  'link',
#  'so',
#  'that',
#  'u',
#  'let',
#  'me',
#  'in',
#  'but',
#  'no',
#  'response,',
#  'can',
#  'u',
#  'please',
#  'make',
#  'sure',
#  'u',
#  'let',
#  'everyone',
#  'immediately',
#  'when',
#  'thy',
#  'request',
#  'join',
#  'in',
#  'still',
#  'waiting',
#  'join',
#  'please',
#  'now',
#  'umar,',
#  'syed',
#  'and',
#  'noor',
#  'please',
#  'join',
#  'meeting',
#  'now',
#  'Yes',
#  'sir',
#  'Yes',
#  'sir',
#  'break',
#  'break',
#  'in',
#  'Break',
#  'in',
#  'break',
#  'out',
#  'Break',
#  'out',
#  'back',
#  'Break',
#  'in',
#  'Check',
#  'out',
#  'check',
#  'out',
#  'check',
#  'out',
#  'Check',
#  'out',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'check',
#  'in',
#  'Today',
#  'I',
#  'am',
#  'off',
#  'break',
#  'in',
#  'break',
#  'out',
#  'break',
#  'in',
#  'break',
#  'out',
#  'break',
#  'back',
#  'break',
#  'in',
#  'Break',
#  'in',
#  'break',
#  'out',
#  'away',
#  '10',
#  'minutes',
#  'back',
#  'Check',
#  'out',
#  'check',
#  'out',
#  'check',
#  'out',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'Check',
#  'in',
#  'check',
#  'in',
#  'Break',
#  'in',
#  'Break',
#  'out',
#  'Break',
#  'in',
#  '10',
#  'minute',
#  'off',
#  'back',
#  'Break',
#  'out',
#  'break',
#  'in',
#  'break',
#  'out',
#  'break',
#  'in',
#  'Break',
#  'Break',
#  'out',
#  '+92',
#  '333',
#  '5010840',
#  'joined',
#  'using',
#  'this',
#  "group's",
#  'invite',
#  'link',
#  'break',
#  'out',
#  'break',
#  'break',
#  'in',
#  'break',
#  'out',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'ase',
#  'Please',
#  'share',
#  'link',
#  'here',
#  'Meet',
#  'link?',
#  'https://meet.google.com/jsy-yueq-mrv',
#  'break',
#  'in',
#  'break',
#  'out',
#  'Sir',
#  'Eut',
#  'Online',
#  'Meeting',
#  'removed',
#  '+92',
#  '346',
#  '3296362',
#  'Break',
#  'in',
#  'Break',
#  'in',
#  'Check',
#  'out',
#  'check',
#  'out',
#  'Check',
#  'out',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'Checkin',
#  'check',
#  'in',
#  'Break',
#  'in',
#  'Break',
#  'out',
#  'Noor/Umar/syed',
#  'calling',
#  'you',
#  'here',
#  'in',
#  '10',
#  'min,',
#  'please',
#  'get',
#  'urself',
#  'available',
#  'yes',
#  'sir',
#  'Ok',
#  'sir',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'Meeting',
#  'Recording',
#  'something',
#  'went',
#  'wrong',
#  'voice',
#  'not',
#  'recorded',
#  'Ok',
#  'no',
#  'problem',
#  'I',
#  'have',
#  'noted',
#  'everything',
#  'what',
#  'has',
#  'been',
#  'delivered',
#  'by',
#  'sir.',
#  'No',
#  'problem',
#  'brother.',
#  'break',
#  'in',
#  'break',
#  'out',
#  'Break',
#  'in',
#  'break',
#  'in',
#  'Break',
#  'break',
#  'out',
#  'back',
#  'Link',
#  'plz',
#  'https://meet.google.com/jsy-yueq-mrv',
#  'Check',
#  'out',
#  'check',
#  'out',
#  'check',
#  'out',
#  'Check',
#  'out',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'check',
#  'in',
#  'break',
#  'in',
#  'Break',
#  'in',
#  'break',
#  'in',
#  'Break',
#  'out',
#  'break',
#  'out',
#  'away',
#  'for',
#  '10',
#  'minutes',
#  'back',
#  'Break',
#  'break',
#  'in',
#  'break',
#  'out',
#  'back',
#  'https://admin.vuestorefronts.com/',
#  'https://nouthemes.net/html/martfury/homepage-4.html',
#  'check',
#  'out',
#  'check',
#  'out',
#  'Check',
#  'out',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'Break',
#  'in',
#  'Check',
#  'in',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'Break',
#  'in',
#  'Break',
#  'out',
#  'Noor/Umar',
#  'wht',
#  'is',
#  'ur',
#  'update',
#  'on',
#  'search',
#  'are',
#  'you',
#  'able',
#  'to',
#  'get',
#  'data',
#  'from',
#  'apis',
#  'Yes',
#  'sir',
#  'i',
#  'did',
#  'it',
#  'We',
#  'get',
#  'your',
#  'post',
#  'man',
#  'data',
#  'and',
#  'develop',
#  'a',
#  'search',
#  'bar',
#  'with',
#  'auto',
#  'suggestions',
#  '@923335010840',
#  'please',
#  'coordinate',
#  'with',
#  'Wasif',
#  'I',
#  'asked',
#  'him',
#  'to',
#  'start',
#  'with',
#  'the',
#  'login',
#  'and',
#  'customer',
#  'record',
#  'filter',
#  'process',
#  'so',
#  'that',
#  'we',
#  'bring',
#  'data',
#  'to',
#  'the',
#  'portal.',
#  'Ok',
#  'sir',
#  'can',
#  'u',
#  'demostrate',
#  ',',
#  'let',
#  'me',
#  'knw',
#  'when',
#  'ready',
#  'Give',
#  'me',
#  'just',
#  '20',
#  'mint',
#  'I',
#  'will',
#  'show',
#  'everything',
#  'right',
#  'there',
#  'at',
#  'meeting',
#  'just',
#  'after',
#  '20',
#  'mints',
#  '+1',
#  '(519)',
#  '731-9331',
#  'added',
#  '+92',
#  '346',
#  '9184015',
#  '@khairullah',
#  'we',
#  'use',
#  'this',
#  'group',
#  'for',
#  'ecommerce',
#  'web',
#  'and',
#  'customer',
#  'portal',
#  'activities',
#  'wasif',
#  'is',
#  '.net',
#  'developer',
#  'and',
#  'he',
#  'is',
#  'working',
#  'on',
#  'email',
#  'functionality',
#  'that',
#  'is',
#  'required',
#  'for',
#  'sign',
#  'in,',
#  'sign',
#  'up,',
#  'forget',
#  'password',
#  'and',
#  'password',
#  'change',
#  'process',
#  '.',
#  'can',
#  'you',
#  'guide',
#  'him',
#  'on',
#  'powershell',
#  'which',
#  'he',
#  'is',
#  'trying',
#  'to',
#  'use',
#  'as',
#  'well',
#  'we',
#  'put',
#  'correct',
#  'email',
#  'id',
#  'and',
#  'password',
#  'in',
#  'web.config',
#  'but',
#  'no',
#  'luck',
#  'Assalam',
#  'o',
#  'Alikum,',
#  'sir',
#  'we',
#  'have',
#  'requested',
#  'data',
#  'from',
#  'postman',
#  'and',
#  'performed',
#  'all',
#  'the',
#  'require',
#  'operation',
#  'on',
#  'it.',
#  'We',
#  'have',
#  'developed',
#  'the',
#  'functionality',
#  'for',
#  'autosuggest.',
#  'Right',
#  'now',
#  'we',
#  'are',
#  'moving',
#  'head',
#  'towards',
#  'creating',
#  'simple',
#  'UI',
#  'for',
#  'it.',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'You',
#  'deleted',
#  'this',
#  'message',
#  'This',
#  'message',
#  'was',
#  'deleted',
#  'coming..',
#  'check',
#  'in',
#  'Okay',
#  'sir',
#  'Can',
#  'you',
#  'please',
#  'share',
#  'email',
#  'details?',
#  'I',
#  'am',
#  'sharing',
#  '<add',
#  'key="Email.SmtpServer"',
#  'value="premium109.web-hosting.com"',
#  '/>',
#  '<add',
#  'key="Email.UserName"',
#  'value="eut@precisetec.ca"',
#  '/>',
#  '<add',
#  'key="Email.Password"',
#  'value="wU)4gQoOpAF6"',
#  '/><!--n*H@5hp$w^=e-->',
#  '<add',
#  'key="Email.BCC"',
#  'value="eut@precisetec.ca"',
#  '/>',
#  '<add',
#  'key="Email.SmtpPort"',
#  'value="465"',
#  '/>',
#  '<add',
#  'key="Email.DisplayName"',
#  'value="Precise',
#  'Technology',
#  '."',
#  '/>',
#  '<add',
#  'key="Email.Domain"',
#  'value="precisetec.ca"',
#  '/>',
#  '<add',
#  'key="Email.EnableSsl"',
#  'value="true"',
#  '/>',
#  '<add',
#  'key="Email.IsUAT"',
#  'value="false"',
#  '/>',
#  '<add',
#  'key="Email.TCSNotificationMail"',
#  'value="eut@precisetec.ca"',
#  '/>',
#  '<add',
#  'key="Email.Proxy"',
#  'value="eut@precisetec.ca"',
#  '/>',
#  '<add',
#  'key="Other"',
#  'value="5"',
#  '/>',
#  '<add',
#  'key="SaveUser"',
#  'value="Y"',
#  '/>',
#  '@923327513954',
#  'can',
#  'you',
#  'please',
#  'let',
#  'me',
#  'in.',
#  'Break',
#  'in',
#  'because',
#  'of',
#  'battery',
#  'dead',
#  'Waiting',
#  'for',
#  'light',
#  'As',
#  'mentioned',
#  'earlier',
#  'there',
#  'is',
#  'a',
#  'reference',
#  'of',
#  'cus_id',
#  'in',
#  'user',
#  'table',
#  'First',
#  'create',
#  'a',
#  'customer',
#  'and',
#  'pass',
#  'that',
#  'id',
#  'to',
#  'user',
#  'table',
#  'Email',
#  'field',
#  'is',
#  'already',
#  'there',
#  'inuser',
#  'table',
#  'I',
#  'know',
#  'but',
#  'actual',
#  'issue',
#  'is',
#  'in',
#  'sending',
#  'email',
#  'from',
#  'PowerShell',
#  'to',
#  'any',
#  'Email',
#  'address',
#  'break',
#  'in',
#  'break',
#  'out',
#  'Break',
#  'out',
#  'break',
#  'smptserver',
#  'not',
#  'responding.',
#  '<Media',
#  'omitted>',
#  'Same',
#  'issue',
#  'with',
#  'me',
#  'CAN',
#  'U',
#  'SEND',
#  'using',
#  'gmail',
#  'account',
#  'whr',
#  'u',
#  'r',
#  '100%',
#  'sure',
#  'email',
#  'is',
#  'working',
#  'back',
#  '<Media',
#  'omitted>',
#  'Sir',
#  'kindly',
#  'check',
#  'search',
#  'engine',
#  'Break',
#  'in',
#  'Break',
#  'out',
#  '<Media',
#  'omitted>',
#  '<Media',
#  'omitted>',
#  'is',
#  'it',
#  'still',
#  'not',
#  'working',
#  '?',
#  'yes',
#  'not',
#  'working',
#  'sending',
#  'with',
#  'Correct',
#  'email',
#  '@923469184015',
#  '@923335010840',
#  '@923335852074',
#  'any',
#  'solution',
#  'for',
#  'this',
#  'issue?',
#  'Break',
#  'in',
#  'break',
#  'in',
#  'Check',
#  'out',
#  'check',
#  'out',
#  'check',
#  'out',
#  'checkout',
#  'check',
#  'in',
#  'Check',
#  'in',
#  'Check',
#  'in',
#  'check',
#  'in']

# %%
# fetch number of media messages
num_media_messages = df[df['message'] == '<Media omitted>\n'].shape[0]

# %%
num_media_messages
# Out:
# 4

# %%
#fetch number of links shared
from urlextract import URLExtract
ex = URLExtract()
links = []
for mess in df['message']:
    print(ex.find_urls(mess))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['https://meet.google.com/jsy-yueq-mrv']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['https://meet.google.com/jsy-yueq-mrv']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['https://admin.vuestorefronts.com/']
# ['https://nouthemes.net/html/martfury/homepage-4.html']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['premium109.web-hosting.com', 'precisetec.ca']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
# most busy user
x = df['user'].value_counts().head()

# %%
x
# Out:
# Wasif Eut                 47
# Umar Aslam                46
# 💻Noor Saeed🗜️             46
# Syed Afaq Shah            21
# Sir Eut Online Meeting    14
# Name: user, dtype: int64

# %%
 df = round((df['user'].value_counts() / df.shape[0]) * 100, 2).reset_index().rename(
        columns={'index': 'name', 'user': 'percent'})

# %%
df
# Out:
#                      name  percent
# 0               Wasif Eut    24.87
# 1              Umar Aslam    24.34
# 2           💻Noor Saeed🗜️    24.34
# 3          Syed Afaq Shah    11.11
# 4  Sir Eut Online Meeting     7.41
# 5      group_notification     3.70
# 6         +92 333 5010840     2.12
# 7         +92 346 9184015     2.12
